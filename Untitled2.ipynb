# %% [markdown]
# <a href="https://colab.research.google.com/github/ckstj8027/practice/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets

d=datasets.load_iris()




from sklearn import svm

#s=svm.SVC(gamma=0.1,c=10)
s = svm.SVC(gamma=0.01, C=10,).fit(d.data, d.target)


#s.fit(d.data, d.target)


new_d=[[6,4,3.2,5],[7.1,3.1,2,5],[7,3,2,6]]

res = s.predict(new_d)

print("새로운 2개 샘플의 부류는",res)
# Out:
# 새로운 2개 샘플의 부류는 [2 1 2]
